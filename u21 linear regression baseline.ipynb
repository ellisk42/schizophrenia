# %%
import pandas as pd
import os
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import datetime
from datetime import timedelta
from scipy.stats import pearsonr
from sklearn.manifold import TSNE
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import LeavePGroupsOut
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
import seaborn as sns
from StudentLife import get_data

# %%
u21 = pd.read_csv('u021_data_filter.csv')

# %%
if 'Unnamed: 0' in u21.columns:
    u21 = u21.drop(['Unnamed: 0'], axis=1)

u21 = u21.dropna(subset=['prev_ema_score'])

# %%
u21.shape
# Out:
# (57, 119)

# %%
u21
# Out:
#            day eureka_id  ema_CALM  ema_DEPRESSED  ema_HARM  ema_HOPEFUL  \
# 0   2015-12-25      u021       1.0            1.0       0.0          1.0
# 2   2015-12-30      u021       1.0            2.0       3.0          2.0
# 3   2016-01-01      u021       1.0            1.0       2.0          1.0
# 4   2016-01-04      u021       1.0            2.0       1.0          2.0
# 5   2016-01-06      u021       1.0            3.0       2.0          3.0
# 6   2016-01-08      u021       1.0            1.0       1.0          2.0
# 7   2016-01-11      u021       1.0            1.0       2.0          1.0
# 8   2016-01-13      u021       1.0            3.0       3.0          1.0
# 9   2016-01-15      u021       2.0            1.0       3.0          2.0
# 10  2016-01-20      u021       2.0            2.0       1.0          2.0
# 11  2016-02-08      u021       1.0            1.0       1.0          0.0
# 12  2016-02-10      u021       1.0            2.0       3.0          1.0
# 13  2016-02-12      u021       1.0            1.0       1.0          1.0
# 14  2016-02-15      u021       3.0            1.0       1.0          1.0
# 15  2016-02-17      u021       1.0            1.0       1.0          1.0
# 16  2016-02-19      u021       1.0            0.0       1.0          0.0
# 17  2016-02-22      u021       0.0            3.0       3.0          0.0
# 18  2016-02-24      u021       1.0            1.0       1.0          2.0
# 19  2016-02-26      u021       1.0            2.0       2.0          3.0
# 20  2016-02-29      u021       1.0            2.0       1.0          3.0
# 21  2016-03-04      u021       1.0            1.0       0.0          1.0
# 22  2016-03-07      u021       0.0            1.0       3.0          0.0
# 23  2016-03-09      u021       1.0            2.0       2.0          0.0
# 24  2016-03-11      u021       1.0            1.0       2.0          2.0
# 25  2016-03-14      u021       1.0            2.0       2.0          1.0
# 26  2016-03-16      u021       1.0            2.0       1.0          0.0
# 27  2016-03-18      u021       1.0            1.0       2.0          0.0
# 28  2016-03-21      u021       1.0            2.0       2.0          2.0
# 29  2016-03-23      u021       2.0            1.0       0.0          3.0
# 30  2016-03-25      u021       1.0            2.0       1.0          1.0
# 31  2016-03-28      u021       1.0            1.0       1.0          3.0
# 32  2016-03-30      u021       1.0            1.0       1.0          1.0
# 33  2016-04-04      u021       1.0            1.0       1.0          1.0
# 34  2016-04-27      u021       1.0            1.0       1.0          1.0
# 35  2016-04-29      u021       1.0            2.0       1.0          1.0
# 36  2016-05-02      u021       1.0            1.0       1.0          1.0
# 37  2016-05-04      u021       1.0            1.0       2.0          1.0
# 38  2016-05-06      u021       1.0            1.0       3.0          0.0
# 39  2016-05-09      u021       1.0            1.0       3.0          2.0
# 40  2016-05-20      u021       1.0            1.0       2.0          2.0
# 41  2016-05-23      u021       1.0            2.0       3.0          2.0
# 42  2016-05-25      u021       2.0            1.0       0.0          1.0
# 43  2016-05-27      u021       2.0            2.0       1.0          1.0
# 44  2016-05-30      u021       1.0            2.0       3.0          2.0
# 45  2016-06-01      u021       1.0            1.0       2.0          1.0
# 46  2016-06-03      u021       1.0            1.0       3.0          0.0
# 47  2016-06-06      u021       2.0            3.0       2.0          2.0
# 48  2016-06-08      u021       1.0            1.0       3.0          1.0
# 49  2016-06-10      u021       1.0            1.0       3.0          2.0
# 50  2016-06-13      u021       1.0            2.0       2.0          1.0
# 51  2016-06-15      u021       3.0            0.0       0.0          3.0
# 52  2016-06-17      u021       1.0            3.0       2.0          1.0
# 53  2016-06-20      u021       1.0            1.0       3.0          0.0
# 54  2016-06-22      u021       1.0            1.0       1.0          0.0
# 55  2016-06-24      u021       1.0            1.0       1.0          3.0
# 56  2016-06-27      u021       1.0            0.0       3.0          3.0
# 57  2016-06-29      u021       2.0            1.0       0.0          3.0
#
#     ema_SEEING_THINGS  ema_SLEEPING  ema_SOCIAL  ema_STRESSED  ...  \
# 0                 1.0           1.0         1.0           1.0  ...
# 2                 2.0           1.0         1.0           1.0  ...
# 3                 1.0           1.0         3.0           2.0  ...
# 4                 1.0           1.0         1.0           1.0  ...
# 5                 0.0           2.0         1.0           1.0  ...
# 6                 1.0           1.0         1.0           1.0  ...
# 7                 2.0           1.0         1.0           1.0  ...
# 8                 1.0           0.0         2.0           3.0  ...
# 9                 3.0           0.0         1.0           3.0  ...
# 10                1.0           2.0         2.0           1.0  ...
# 11                1.0           1.0         1.0           1.0  ...
# 12                3.0           0.0         1.0           3.0  ...
# 13                1.0           1.0         1.0           1.0  ...
# 14                1.0           0.0         2.0           1.0  ...
# 15                1.0           1.0         1.0           1.0  ...
# 16                1.0           1.0         1.0           1.0  ...
# 17                3.0           0.0         0.0           3.0  ...
# 18                1.0           1.0         2.0           1.0  ...
# 19                1.0           1.0         2.0           1.0  ...
# 20                1.0           2.0         2.0           0.0  ...
# 21                1.0           3.0         1.0           2.0  ...
# 22                3.0           1.0         1.0           3.0  ...
# 23                1.0           1.0         1.0           2.0  ...
# 24                1.0           1.0         3.0           1.0  ...
# 25                2.0           2.0         1.0           2.0  ...
# 26                3.0           1.0         1.0           2.0  ...
# 27                2.0           2.0         2.0           2.0  ...
# 28                3.0           1.0         1.0           3.0  ...
# 29                2.0           1.0         1.0           1.0  ...
# 30                1.0           2.0         1.0           2.0  ...
# 31                1.0           1.0         2.0           2.0  ...
# 32                2.0           1.0         1.0           1.0  ...
# 33                1.0           1.0         1.0           1.0  ...
# 34                1.0           2.0         2.0           1.0  ...
# 35                2.0           1.0         1.0           1.0  ...
# 36                1.0           1.0         2.0           2.0  ...
# 37                2.0           1.0         1.0           1.0  ...
# 38                3.0           2.0         1.0           3.0  ...
# 39                1.0           2.0         1.0           3.0  ...
# 38                       13.0             3.0
# 39                       13.0             1.0
# 40                       13.0            -3.0
# 41                       13.0            -1.0
# 42                       13.0            -2.0
# 43                       14.0             4.0
# 44                       14.0             5.0
# 45                       14.0            -2.0
# 46                       14.0            -3.0
# 47                       14.0             2.0
# 48                       14.0             1.0
# 49                       14.0             3.0
# 50                       14.0             7.0
# 51                       14.0             6.0
# 52                       14.0             4.0
# 53                       14.0            -1.0
# 54                       14.0           -13.0
# 55                       13.0             9.0
# 56                       12.0            10.0
# 57                       12.0             3.0
#
# [57 rows x 119 columns]

# %%
for item in u21.columns:
    print(item)
# Out:
# day
# eureka_id
# ema_CALM
# ema_DEPRESSED
# ema_HARM
# ema_HOPEFUL
# ema_SEEING_THINGS
# ema_SLEEPING
# ema_SOCIAL
# ema_STRESSED
# ema_THINK
# ema_VOICES
# ema_neg_score
# ema_pos_score
# ema_resp_time_median
# ema_score
# calllog_med_mean
# calllog_med_mean_normal
# calllog_med_mean_raw
# calllog_avg
# calllog_std
# calllog_num_good_days
# sms_in_med_mean
# sms_in_med_mean_normal
# sms_in_med_mean_raw
# sms_in_avg
# sms_in_std
# sms_in_num_good_days
# sms_out_med_mean
# sms_out_med_mean_normal
# sms_out_med_mean_raw
# sms_out_avg
# sms_out_std
# sms_out_num_good_days
# unlock_med_mean
# unlock_med_mean_normal
# unlock_med_mean_raw
# unlock_avg
# unlock_std
# unlock_num_good_days
# conver_med_mean
# conver_med_mean_normal
# conver_med_mean_raw
# conver_avg
# conver_std
# conver_num_good_days
# sleep_med_mean
# sleep_med_mean_normal
# sleep_med_mean_raw
# sleep_avg
# sleep_std
# sleep_num_good_days
# act_invehicle_med_mean
# act_invehicle_med_mean_normal
# act_invehicle_med_mean_raw
# act_invehicle_avg
# act_invehicle_std
# act_invehicle_num_good_days
# act_onbike_med_mean
# act_onbike_med_mean_normal
# act_onbike_med_mean_raw
# act_onbike_avg
# act_onbike_std
# act_onbike_num_good_days
# act_onfoot_med_mean
# act_onfoot_med_mean_normal
# act_onfoot_med_mean_raw
# act_onfoot_avg
# act_onfoot_std
# act_onfoot_num_good_days
# act_still_med_mean
# act_still_med_mean_normal
# act_still_med_mean_raw
# act_still_avg
# act_still_std
# act_still_num_good_days
# act_tilting_med_mean
# act_tilting_med_mean_normal
# act_tilting_med_mean_raw
# act_tilting_avg
# act_tilting_std
# act_tilting_num_good_days
# act_unknown_med_mean
# act_unknown_med_mean_normal
# act_unknown_med_mean_raw
# act_unknown_avg
# act_unknown_std
# act_unknown_num_good_days
# light_med_mean
# light_med_mean_normal
# light_med_mean_raw
# light_avg
# light_std
# light_num_good_days
# audio_amp_med_mean
# audio_amp_med_mean_normal
# audio_amp_med_mean_raw
# audio_amp_avg
# audio_amp_std
# audio_amp_num_good_days
# audio_noise_med_mean
# audio_noise_med_mean_normal
# audio_noise_med_mean_raw
# audio_noise_avg
# audio_noise_std
# audio_noise_num_good_days
# audio_silence_med_mean
# audio_silence_med_mean_normal
# audio_silence_med_mean_raw
# audio_silence_avg
# audio_silence_std
# audio_silence_num_good_days
# audio_voice_med_mean
# audio_voice_med_mean_normal
# audio_voice_med_mean_raw
# audio_voice_avg
# audio_voice_std
# audio_voice_num_good_days
# prev_ema_score

# %%
u21['calllog_med_mean_normal']
# Out:
# 0     0.847464
# 2     0.862084
# 3     0.886649
# 4     0.860674
# 5     0.864847
# 6     0.851288
# 7     0.851429
# 8     0.818749
# 9     0.814213
# 10    0.830263
# 11    0.835647
# 12    0.840705
# 13    0.819513
# 14    0.808829
# 15    0.807168
# 16    0.826649
# 17    0.819471
# 18    0.826649
# 19    0.794464
# 20    0.794885
# 21    0.761979
# 22    0.758262
# 23    0.797174
# 24    0.824315
# 25    0.829501
# 26    0.829501
# 27    0.834711
# 28    0.844774
# 29    0.829501
# 30    0.855288
# 31    0.833760
# 32    0.832596
# 33    0.840273
# 34    0.830888
# 35    0.819612
# 36    0.810921
# 37    0.802623
# 38    0.800513
# 39    0.800513
# 40    0.816645
# 41    0.820398
# 42    0.829168
# 43    0.830507
# 44    0.845493
# 45    0.838205
# 46    0.830675
# 47    0.825003
# 48    0.846568
# 49    0.851188
# 50    0.863013
# 51    0.891485
# 52    0.901063
# 53    0.892440
# 54    0.888054
# 55    0.900139
# 56    0.888461
# 57    0.845299
# Name: calllog_med_mean_normal, dtype: float64

# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
lpgo = LeavePGroupsOut(n_groups=1)

# %%
EMA_ITEM = 'ema_score'

# %%
X = u21
y = u21[EMA_ITEM]

# %%
ema = X

# %%
baseline = [c for c in ema.columns if 'avg' in c or 'std' in c]
just_diff = [c for c in ema.columns if 'med_mean' in c and 'raw' not in c]
just_diff_absolute = [c for c in ema.columns if 'med_mean' in c and 'normal' not in c and 'raw' not in c]
just_diff_normal = [c for c in ema.columns if 'med_mean_normal' in c]
raw_fea = [c for c in ema.columns if 'raw' in c]
all_fea = just_diff + baseline 
prev_ema = [c for c in ema.columns if ('prev_' + EMA_ITEM) in c]
all_fea_prev_ema = all_fea + prev_ema
baseline_diff_absolute = baseline + just_diff_absolute
baseline_diff_normal = baseline + just_diff_normal
baseline_diff_raw = baseline + raw_fea
all_fea_raw = all_fea + raw_fea
print('length of baseline should be 34:', len(baseline))
print('length of just_diff_normal should be 17:', len(just_diff_normal))
print('length of baseline_diff_normal should be 51:', len(baseline_diff_normal))


feature_sets = [
    prev_ema,
    prev_ema,
    baseline,
    just_diff_normal,
    baseline_diff_normal,
]
feature_sets_names = [
    'prev_ema',
    'mean_predictor',
    'baseline_mean_std',
    'just_diff_normal',
    'baseline_diff_normal',
]
# Out:
# length of baseline should be 34: 34
# length of just_diff_normal should be 17: 17
# length of baseline_diff_normal should be 51: 51

# %%
selected_fea = baseline

# %%
X = X[baseline]

# %%
y
# Out:
# 0     -1.0
# 2      4.0
# 3      1.0
# 4      0.0
# 5     -1.0
# 6     -1.0
# 7      3.0
# 8      6.0
# 9      8.0
# 10    -3.0
# 11     1.0
# 12    11.0
# 13     0.0
# 14    -1.0
# 15     0.0
# 16     0.0
# 17    15.0
# 18    -2.0
# 19    -1.0
# 20    -4.0
# 21    -3.0
# 22     9.0
# 23     5.0
# 24    -2.0
# 25     4.0
# 26     4.0
# 27     2.0
# 28     7.0
# 29    -4.0
# 30     2.0
# 31    -2.0
# 32     1.0
# 33     0.0
# 34    -3.0
# 35     3.0
# 36     1.0
# 37     3.0
# 38     8.0
# 39     3.0
# 40     4.0
# 41     5.0
# 42    -2.0
# 43    -3.0
# 44     2.0
# 45     1.0
# 46     3.0
# 47     7.0
# 48     6.0
# 49     4.0
# 50    -1.0
# 51   -13.0
# 52     9.0
# 53    10.0
# 54     3.0
# 55    -1.0
# 56     6.0
# 57    -6.0
# Name: ema_score, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0, shuffle=False)

# %%
from sklearn.preprocessing import StandardScaler

scalerx = StandardScaler()
scalerx.fit(X_train)

X_train = scalerx.transform(X_train)
X_test = scalerx.transform(X_test)

scalery = StandardScaler()
scalery.fit(X_train)

# %%
X_train.shape
# Out:
# (38, 34)

# %%
X_test.shape
# Out:
# (19, 34)

# %%
# from sklearn.linear_model import LinearRegression
# regressor = LinearRegression()
# regressor.fit(X_train, y_train)

# %%
# y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LinearRegression
# regressor = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1]).fit(X_train, y_train)
regressor = LinearRegression().fit(X_train, y_train)

# %%
regressor.coef_
# Out:
# array([ 8.84413058e+00, -1.88484438e+01, -8.32430012e+00, -9.16195284e+00,
#         8.42362251e+00,  1.41649308e+01,  2.37786642e+01, -2.05904981e+01,
#         5.63216834e+00, -3.31255507e+00, -5.89229568e+00,  3.33384297e+00,
#         1.88525127e+14, -8.37375378e+00,  7.51146412e+12,  1.83913453e+01,
#         1.51718847e+14,  9.22264568e+00,  2.04500550e+14,  1.81775501e+00,
#         1.17440124e+14, -1.23062236e-01,  1.97065701e+14,  5.11597115e-01,
#        -1.29727816e+01,  9.94005531e+00, -1.96286428e+01, -2.80152033e+00,
#        -4.19079092e+13,  1.79742825e+01, -4.72149353e+13, -2.33951671e+01,
#        -1.44707696e+13, -5.02686816e+00])

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred_train = regressor.predict(X_train)

# %%
# df = pd.DataFrame({'Actual': y_test.values.flatten(), 'Predicted': y_pred.flatten()})
# df

# %%
print('Mean Squared Error test linear:', metrics.mean_squared_error(y_test, y_pred))
print('Mean Squared Error train linear:', metrics.mean_squared_error(y_train, y_pred_train))
# Out:
# Mean Squared Error test linear: 46777.75107588637
# Mean Squared Error train linear: 3.1158099814646376

# %%
print('Mean Absolute Error test:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Absolute Error train:', metrics.mean_absolute_error(y_train, y_pred_train))
# Out:
# Mean Absolute Error test linear: 168.4491736076073
# Mean Absolute Error train linear: 1.5284605611657063

# %%
#ridge

# %%
regressor = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1]).fit(X_train, y_train)

# %%
regressor.coef_
# Out:
# array([-0.42638119, -0.59492173,  0.69145946,  0.13273582, -0.60194871,
#         1.93119161,  2.18177495, -0.95145471, -0.4700947 , -0.96598167,
#        -1.92027079,  1.43715764,  0.11770595, -1.73458381,  0.5376356 ,
#         2.76469971, -1.86155252,  2.73030587, -1.00637445,  1.69104734,
#         2.26077241, -3.18559744,  0.99714146, -0.51723549, -2.49710637,
#        -0.51313649, -1.05191049, -1.40695245,  0.70448026,  1.09498188,
#        -0.96653017,  0.11236425,  1.11337303, -0.34045593])

# %%
y_pred = regressor.predict(X_test)
y_pred_train = regressor.predict(X_train)

# %%
# df = pd.DataFrame({'Actual': y_test.values.flatten(), 'Predicted': y_pred.flatten()})
# df

# %%
print('Mean Squared Error test ridge:', metrics.mean_squared_error(y_test, y_pred))
print('Mean Squared Error train ridge:', metrics.mean_squared_error(y_train, y_pred_train))
# Out:
# Mean Squared Error test ridge: 46777.75107588637
# Mean Squared Error train ridge: 3.1158099814646376

# %%
print('Mean Absolute Error test:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Absolute Error train:', metrics.mean_absolute_error(y_train, y_pred_train))
# Out:
# Mean Absolute Error test: 168.4491736076073
# Mean Absolute Error train: 1.5284605611657063

# %%
params = {'n_estimators': 300, 'max_depth': 3, 'min_samples_split': 2, 'learning_rate': 0.17} 
regressor = GradientBoostingRegressor(**params).fit(X_train, y_train)

# %%
y_pred = regressor.predict(X_test)
y_pred_train = regressor.predict(X_train)

# %%
# df = pd.DataFrame({'Actual': y_test.values.flatten(), 'Predicted': y_pred.flatten()})
# df

# %%
print('Mean Squared Error test gradient boost:', metrics.mean_squared_error(y_test, y_pred))
print('Mean Squared Error train gradient boost:', metrics.mean_squared_error(y_train, y_pred_train))
# Out:
# Mean Squared Error test gradient boost: 35.13560109541425
# Mean Squared Error train gradient boost: 1.228543075065173e-13

# %%
print('Mean Absolute Error test:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Absolute Error train:', metrics.mean_absolute_error(y_train, y_pred_train))
# Out:
# Mean Absolute Error test: 4.431479157330937
# Mean Absolute Error train: 3.1822149966468087e-07

# %%
from sklearn.linear_model import SGDRegressor
regressor = SGDRegressor(penalty='l2', max_iter=1000, random_state=42).fit(X_train, y_train)

# %%
y_pred = regressor.predict(X_test)
y_pred_train = regressor.predict(X_train)

# %%
print('Mean Squared Error test gradient boost:', metrics.mean_squared_error(y_test, y_pred))
print('Mean Squared Error train gradient boost:', metrics.mean_squared_error(y_train, y_pred_train))
# Out:
# Mean Squared Error test gradient boost: 2177.5419708412696
# Mean Squared Error train gradient boost: 8.890898906924471

# %%
print('Mean Absolute Error test:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Absolute Error train:', metrics.mean_absolute_error(y_train, y_pred_train))
# Out:
# Mean Absolute Error test: 35.49500946168873
# Mean Absolute Error train: 2.1154204584885647

# %%
from sklearn import linear_model
regressor = linear_model.BayesianRidge().fit(X_train, y_train)
y_pred = regressor.predict(X_test)
y_pred_train = regressor.predict(X_train)
print('Mean Squared Error test gradient boost:', metrics.mean_squared_error(y_test, y_pred))
print('Mean Squared Error train gradient boost:', metrics.mean_squared_error(y_train, y_pred_train))
# Out:
# Mean Squared Error test gradient boost: 28.374663686291598
# Mean Squared Error train gradient boost: 18.393700758165146

# %%
print('Mean Absolute Error test:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Absolute Error train:', metrics.mean_absolute_error(y_train, y_pred_train))
# Out:
# Mean Absolute Error test: 4.093828730987689
# Mean Absolute Error train: 3.395813216145149

# %%
from sklearn import linear_model
regressor = linear_model.ARDRegression().fit(X_train, y_train)
y_pred = regressor.predict(X_test)
y_pred_train = regressor.predict(X_train)
print('Mean Squared Error test gradient boost:', metrics.mean_squared_error(y_test, y_pred))
print('Mean Squared Error train gradient boost:', metrics.mean_squared_error(y_train, y_pred_train))
# Out:
# Mean Squared Error test gradient boost: 28.337620629997062
# Mean Squared Error train gradient boost: 18.18097235741795

# %%
print('Mean Absolute Error test:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Absolute Error train:', metrics.mean_absolute_error(y_train, y_pred_train))
# Out:
# Mean Absolute Error test: 4.100878179543462
# Mean Absolute Error train: 3.3890625976405766

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
regressor = GaussianProcessRegressor().fit(X_train, y_train)
y_pred = regressor.predict(X_test)
y_pred_train = regressor.predict(X_train)
print('Mean Squared Error test:', metrics.mean_squared_error(y_test, y_pred))
print('Mean Squared Error train:', metrics.mean_squared_error(y_train, y_pred_train))

print('Mean Absolute Error test:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Absolute Error train:', metrics.mean_absolute_error(y_train, y_pred_train))
# Out:
# Mean Squared Error test: 32.148252496814244
# Mean Squared Error train: 2.3908734717954468e-19
# Mean Absolute Error test: 4.682595223852079
# Mean Absolute Error train: 3.4813533775507144e-10
